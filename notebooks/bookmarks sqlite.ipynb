# %%
import requests
from bs4 import BeautifulSoup
import sqlite3
import os
import urllib
from retry import retry
import time
import pdb
from tqdm.notebook import tqdm 
import sqlite3
from ratelimiter import RateLimiter
import re
from ao3 import AO3
from ao3.works import Work as AWork
from math import ceil
import sqlalchemy
from datetime import datetime

from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import (Column, Integer, String, JSON, 
                        ForeignKey, Table, DateTime)
from sqlalchemy.orm import relationship, Session, configure_mappers

# %% [markdown]
# ##### schema

# %%
engine = sqlalchemy.create_engine('sqlite:///kudos.db')
# engine = sqlalchemy.create_engine('sqlite:///:memory:')
Base = declarative_base()


kudos_table = Table('kudos', Base.metadata,
    Column('user', String, ForeignKey('users.id')),
    Column('work', Integer, ForeignKey('works.id')),
    extend_existing=True
)

bookmarks_table = Table(
    'bookmarks',
    Base.metadata,
    Column('user', String, ForeignKey('users.id')),
    Column('work', Integer, ForeignKey('works.id')),
    extend_existing=True
)

class User(Base):
    __tablename__ = 'users'
    __table_args__ = {'extend_existing': True} 

    id = Column(String, primary_key=True)
    works = relationship('Work', backref='author')
    bookmarks_ts = Column(DateTime, nullable=True)
    
    def __repr__(self):
        return f"User(id='{self.id}')"

    
class Work(Base):
    __tablename__ = 'works'
    __table_args__ = {'extend_existing': True} 

    id = Column(Integer, primary_key=True)
    title = Column(String)
    author_id = Column(String, ForeignKey('users.id'), nullable=True)
    json=Column(JSON, nullable=True)

    
    def __repr__(self):
        return f"Work(id={repr(self.id)}, \"{self.title}\" by {self.author.id})"

    kudos = relationship("User",
                    secondary=kudos_table,
                    backref='kudos')
    
    bookmarks = relationship("User",
                secondary=bookmarks_table,
                backref='bookmarks')
    
    bookmarks_ts = Column(DateTime, nullable=True)

    

Base.metadata.create_all(engine)

# %%
session = Session(bind=engine)
conn = engine.connect()

# %%
ratelimiter = RateLimiter(max_calls=2, period=6.667)

# %% [markdown]
# ##### scraping

# %%
works = session.query(Work).all()
users = session.query(User).all()

# %%
s = requests.Session()
s.headers['user-agent'] = 'robot'

# %%
@retry(RuntimeError, tries=5, delay=2, backoff=5, max_delay=600)
def helper(url):
    with ratelimiter:
        resp = s.get(url)
    if resp.status_code != 200:
        if resp.status_code == 429:
            raise RuntimeError("Rate limit reached")
        else:
            resp.raise_for_status()
            
    return resp

def get_max_pages(soup):
    pages =soup.find('ol', role='navigation')
    if pages:
        max_pages = int(pages.find_all('li')[-2].text)
        return max_pages
    return 1

def process_page(soup):    
    bookmarks=soup.find_all('h5', class_='byline heading')
    bookmark_users = []
    for x in bookmarks:
        if not (x.a):
            continue
        bookmark_users.append(x.a['href'].split('/')[2])
    return bookmark_users

def estimate_bookmark_pages(work):
    if m := re.search(r'"bookmarks": (\d+),',work.json):
        return ceil(int(m.group(1))/20)
    print(f"Couldn't estimate pages for {work}")

def get_bookmarks_for_work(work, pbar = None):
    url=f'https://www.archiveofourown.org/works/{work.id}/bookmarks'
    resp = helper(url)
    soup = BeautifulSoup(resp.content)
    max_pages = get_max_pages(soup)
    if pbar:
        est_pages = estimate_bookmark_pages(work)
        if max_pages != est_pages:
            pbar.total += max_pages - est_pages
            
    users = process_page(soup)
    if pbar:
        pbar.update(1)
    for i in range(2, max_pages+1):
        resp = helper(url+f'?page={i}')
        users += process_page(BeautifulSoup(resp.content))
        if pbar:
            pbar.update(1)
    return users

def get_total_bookmark_pages(works):
    agg = 0
    for work in works:
        agg += estimate_bookmark_pages(work)
    return agg

def register_bookmarks_to_work(work, bookmarks, user_set):
    work.bookmarks = []
    for username in set(bookmarks):
        if username in user_set:
            work.bookmarks.append(session.query(User).get(username))
        else:
            work.bookmarks.append(User(id=username))
            user_set.add(username)
    work.bookmarks_ts = datetime.now()
    session.commit()

# %%
def process_works(works, user_set=None):
    est = get_total_bookmark_pages(works)
    with tqdm(total=est) as pbar:
        for work in works:
            pbar_start = pbar.n
            try:
                if work.bookmarks_ts:
                    raise Exception("Work already has bookmarks")
                bookmarks = get_bookmarks_for_work(work, pbar)
                register_bookmarks_to_work(work, bookmarks, user_set)
            except Exception as e:
                session.rollback()
                print(f"Couldn't process {work}")
                print(e)
                pbar.total -= estimate_bookmark_pages(work)
                pbar.n = pbar_start

# %%
user_set = set(map(lambda x: x[0], session.query(User.id)))
est = get_total_bookmark_pages(works)

# %%
with tqdm(total=est) as pbar:
    for work in works:
        pbar_start = pbar.n
        try:
            if work.bookmarks_ts:
                raise Exception("skip")
            bookmarks = get_bookmarks_for_work(work, pbar)
            register_bookmarks_to_work(work, bookmarks, user_set)
        except Exception as e:
            if 'skip' not in str(e):
                session.rollback()
                print(f"Couldn't process {work}")
                print(e)
                pbar.n = pbar_start                
            pbar.total -= estimate_bookmark_pages(work)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=18086.0), HTML(value='')))
# Couldn't process Work(id=20114854, "Was it my Fault?" by GarbageFanfics)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/20114854/bookmarks
# Couldn't process Work(id=20189578, "Uninvited" by GarbageFanfics)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/20189578/bookmarks
# Couldn't process Work(id=24283147, "Don't Let the Bed Bugs Bite." by BlazingNerz)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/24283147/bookmarks
# Couldn't process Work(id=24307228, "We Must Be Strong" by BlazingNerz)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/24307228/bookmarks
# Couldn't process Work(id=24334198, "-Message Incoming-" by BlazingNerz)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/24334198/bookmarks
# Couldn't process Work(id=25987297, ""I Just Came Here To The Party For The-"" by smalltiddygothgf)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/25987297/bookmarks
# Couldn't process Work(id=26997799, "So Much and Not Enough" by cloudtreesium)
# ('Connection aborted.', TimeoutError(10060, 'A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond', None, 10060, None))
# Couldn't process Work(id=28396797, "Crushes" by aherdofturtles17)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/28396797/bookmarks
# Couldn't process Work(id=28417080, ""Stay."" by aherdofturtles17)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/28417080/bookmarks
# Couldn't process Work(id=28419993, "Cut My Hair" by aherdofturtles17)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/28419993/bookmarks
# Couldn't process Work(id=29680797, "Useless child" by HushBekk)
# 404 Client Error: Not Found for url: https://www.archiveofourown.org/works/29680797/bookmarks

# %%
user_set
# Out:
# {'apartment',
#  'AuddaxEnderDragon',
#  'simberthalutz',
#  'Lovely_Lies',
#  'Just_Roman_Around',
#  'Quetampatolles',
#  'lauralizzie',
#  'dicksp8jr',
#  'beingelsewhere',
#  'GarlicPigs',
#  'Jyair_M',
#  'heidzz',
#  'melekinh',
#  'RabbitofWhite',
#  'Adam29',
#  'LightsThatNeverGoOut',
#  'Awesome_Know_It_All',
#  'GlassOwls',
#  'MaddieMare',
#  'LibraryMinion',
#  'princessparkmanor',
#  'SimonKilnsworth',
#  'BunnieLouise',
#  'mostlymeh',
#  'BearShapedBastard',
#  'telracsactually',
#  'sospn',
#  'Lady_Romanoff',
#  'tellyisdreaming',
#  'WereAh',
#  'blooplesnoot',
#  'irumimii',
#  'CBeanz',
#  'chiminies',
#  'Didiza',
#  'Auxcouleur',
#  'Sbear45',
#  'WolfyGames14',
#  'bluemoonbibliophile',
#  '8Antisocial_hyooman8',
#  'minjiyoo',
#  'ill_interrogate_the_cat_castiel',
#  'gaykoifish',
#  'Rowboat129',
#  'alien__puppy',
#  'ErrorScreen',
#  'Lowqualityenglish',
#  'MaryIsANerd',
#  'FMusik',
#  'georgiou',
#  'Brooklin',
#  'Camandrea7',
#  'UponACrowsWing',
#  'Ashstorm160',
#  'Death_Madness',
#  'spiiderblurbs',
#  'zomnic',
#  'vampwagner',
#  '5elma',
#  'helphelp11',
#  'catgirlswag',
#  'Transtatic_Trash',
#  'galateaGalvanized',
#  'Midnight_Owl2',
#  'rainyroyale',
#  'MeepMrp',
#  'seante',
#  'Purple_Dragon096',
#  'felios_farkus',
#  'Riptied',
#  'ziim',
#  'Sensoray',
#  'LadyFire',
#  'ShepardBumbleby',
#  'lexixoxomaria',
#  'sugoiharu',
#  'NCycy',
#  'AbnormalPancake',
#  'demigodavenger',
#  'ephemerasouls',
#  'rainbowskissors',
#  'Grumpy_Matt',
#  'CherryBxmb',
#  'improbableZero',
#  'I_have_no_life_I_am_Karma',
#  'Hamtaru420',
#  'PrimeLegion501',
#  'ioona',
#  'erinalice',
#  'Asiduusnihil',
#  'captain_0bvi0us',
#  'lostinsnow',
#  'nelsmels',
#  'skeedoodle',
#  'zaraaa',
#  'Nyx_080',
#  'Rosa2495',
#  'E_005',
#  'bonamb',
#  'fadainsignificante',
#  'lazyash',
#  'SomeoneNotThatImportant',
#  'mytearsricochet',
#  'ashley_luv',
#  'the_paranoid_pachyderm',
#  'theflowergarden',
#  'Astyrra',
#  'Guilty_treasures',
#  'MokkiMoka',
#  'Lyrica_Lilac',
#  'alpha49',
#  'NLockhart',
#  '0fucs2giv',
#  'kodakquality',
#  'JustADamFanficReader',
#  'GwenTheButtSlut',
#  'Morg_and_amour',
#  'Mila01',
#  'Smarie1',
#  'HaleMikaelsonObsessed',
#  'BlakeQuinn',
#  'punknouis',
#  'milliereads',
#  'Gaypalss',
#  'HeroOfStrangeness',
#  'Nisswen41',
#  'Sylversamthefae',
#  'kidshark',
#  'MoonlightPrincess',
#  'gaymityblight',
#  'infinityshipper',
#  'Queertho',
#  'Rictorrin',
#  'MunchkinLivy',
#  'Punk_Goblin',
#  'Deadl_Pingj',
#  'rreyy',
#  'NeoSeoul',
#  'notsosabrina',
#  'LenaFT',
#  'theevilburrito',
#  'designedship',
#  'trashtierhyena',
#  'loganhunter2',
#  'EmmyStarlight',
#  'Hit_of_E',
#  'laymedowninsheetsoflinen',
#  'WestMokl2k19',
#  'yolo23',
#  'literal_garbage_person',
#  'Jokaste_1',
#  'NoraWarrior',
#  'luniarcine',
#  'queenoffeary',
#  'N001',
#  'pinkmagnolias',
#  'captainmaolord',
#  'Dxoltra',
#  'Soch',
#  'dr_universe',
#  'Nikol_Nikiforova',
#  'Charliesmusings',
#  'Mehveian',
#  'plotholes_and_paradoxes',
#  'snailparty1',
#  'flowersforme',
#  'ThePrettyTomboy',
#  'Mighty_Wangeda',
#  'Tyromund',
#  'Sir_Chaos_Omega',
#  'Vale2710',
#  'Phoenix_of_Athena',
#  'MiserableMesses',
#  'space_sloth',
#  'CretaceousCryptid',
#  'crimsonwolfy4',
#  'Realistic_Dreamer',
#  'Zezily',
#  'Fleurrie',
#  'cosmics4ns',
#  'Keys54321',
#  'justforkicks0422',
#  'coldname',
#  'Sagemistakes',
#  'Nonhygge',
#  'CuppaCreamTea',
#  'YaoiObsessed',
#  'sumamonie',
#  'EmpressLucie',
#  'emmaleda',
#  'junpolni',
#  'venomous_syfy',
#  'xMERIELE',
#  'InvisibleVampire97',
#  'Shiroyasha_Gin',
#  'Nuii',
#  'aheshke',
#  'Xyla06',
#  'Howlshair09',
#  'notbethiguess',
#  'agabas',
#  'toomanyfrogs',
#  'Emm98',
#  'Lespoon',
#  'l0g4nb3rry',
#  'Yang_bangarang',
#  'its_a_supernatural_love',
#  'verycherrychill',
#  'lemonslife',
#  'S_Nebulosa',
#  'JadeDawn',
#  'InuitGirl67',
#  'Marbot457',
#  'MusicloverofMarvel61880',
#  'Milkshake_Boi',
#  'DragonBandit',
#  'moviebuff123',
#  'Yoneiey',
#  'blue_slate',
#  'AnimeBeaver95',
#  'Shinzu',
#  'Loverofstories98',
#  'hi_its_alice',
#  'usure',
#  'gabbyguppy',
#  'therealalberta',
#  'Paintwhisker',
#  'theworldswecantsee',
#  'DrafteeDragon',
#  'Fazekats',
#  'Sciani',
#  'heyyadora',
#  'Juddzilla',
#  'sleepyntired',
#  'super_rainbow2021',
#  'YourLocalTheaterKid',
#  'NightBearrors',
#  'TigerPippy',
#  'canofsprites',
#  'Adortrafin',
#  'IIsMadMan97',
#  'SarahLaDuchesse',
#  'TheCokeworthCauldrons',
#  'KeenestGreen',
#  'flyingdangernoodle',
#  'menacinggiggles',
#  'Ericabrt',
#  'Zafynah',
#  'FelanLupus',
#  'MewAllDay',
#  'hearty_durian',
#  'anatomie',
#  'corpsemin',
#  'FlyingFleshEater',
#  'ItCameFromTheDeep',
#  'BubblySunshine',
#  'toastedtofu',
#  'demiboy_demon',
#  'Beanbogs',
#  'Ghost0313',
#  'Ick_witch',
#  'alizard26',
#  'RowanJay78',
#  'PayNoTaxes',
#  'BloodandBlackRose',
#  'Kai_Xio',
#  'Orphicadmium',
#  'canned_tomatoes',
#  'LadyHood',
#  'LittleBlackSquashBalls',
#  'Somemusicaltrash667',
#  'Skylerwestt',
#  'Xaidil',
#  'Kattttt98',
#  'CuriousWandererSquared',
#  'MadAsTheHatters',
#  'alter__idem',
#  'SeasideFantasties',
#  'Unicat121',
#  'xenostalgic',
#  'peppermintlegs',
#  'AWeirdFan',
#  'Pipper_Fine',
#  'Tineye1',
#  'Thannatos',
#  'indecisivemess',
#  'judlikestoread',
#  'OTPAlchemist99',
#  'Professional_Creeper',
#  'WillTestForCake',
#  'csicameron',
#  'Isabel_villa',
#  'AlienBoi1303',
#  'Cruciferous_Jex',
#  'Gorro',
#  'Stevonnie_and_Bonnie',
#  'DorgaJohn',
#  'Ryder_fanficlover',
#  'SiKumiho',
#  'JaggedwingedWolf',
#  'marielou8',
#  'cherri',
#  'grit',
#  'Loxsky',
#  'cuddle_bugg',
#  'NeufPaprika',
#  'TeacupFun',
#  'AlienBitch555',
#  'ItsonCrouton',
#  'Ur_homie_Blaize',
#  'Mifack',
#  'CanonMostlySucks',
#  'Meep575',
#  'WyvernWitch',
#  'najak3',
#  'Catrastrophic',
#  'TheRealisticSaleh',
#  'em0_r4t',
#  'bloolions',
#  'Esdeath1212',
#  'nataliving',
#  'LunalitSol',
#  'omgitsrayssa',
#  'unfilteredinferno',
#  'Lostboy_Laurens',
#  '10zombi',
#  'Loony_Light_87',
#  'mxcoh',
#  'YaBoiCC',
#  'OnceUponAGirl2237',
#  'zelli',
#  'Cythrul',
#  'bbangnyult',
#  'Dtox',
#  'retroghosts',
#  'bokuto_is_akaashis_star',
#  'BiaTheAdventurer',
#  'ExhaustedCoinshot',
#  'Markthewolf',
#  'Johannas_Motivational_Insults',
#  'SirChinnigan',
#  'looking_for_the_draco_to_my_harry',
#  'odetostark',
#  'milkcart',
#  'shadowhokage',
#  'DigitalThespian',
#  'glimadoracuties',
#  'Moon_Princess27',
#  'FrostJarl',
#  'couldyoubetender',
#  'Sylla_Headhunter',
#  'Cat_ra3',
#  'wanderingcentaur',
#  'Shybiandreadytodie',
#  'GreySilhouette',
#  'SealesChernyh',
#  'Sharkmonth',
#  'markoftara',
#  'summerwoodsmoke',
#  'ReneeWriting',
#  'Yaxxm',
#  'TheMichine',
#  'Hellb0y',
#  'Shadowy_Dumbo_Octopus',
#  'ShaakVe',
#  'DCchick86',
#  'musichealsscars',
#  'FriendlyCybird',
#  'Zarion',
#  'Allurite',
#  'Introvert_On_a_BoAt',
#  'Fanfic_obsessor1029',
#  'LSFRevanfan29',
#  'Ashrel_BN',
#  'BetterNameToCome',
#  'Qaje',
#  'treetops',
#  'PearlDefiance',
#  'EmMakesSomeStuff',
#  'Eliate13',
#  'emdunny',
#  'Taz97',
#  'TakingOverMidnight3482',
#  'thewaterbeneathyou',
#  'blackglass',
#  'tiedupwithstring',
#  'frozenocarina',
#  'Moonflower_girl',
#  'Yazoo',
#  'SpaceMcCowboy',
#  'TokiMudkip',
#  'DawnGreyHelensdaughter',
#  'HyenaGlasses',
#  'rougemidnight03',
#  'GayBean',
#  'Shaladaze',
#  'emmaleejackson',
#  'RoryThePotato',
#  'sammietheaveragegirl',
#  'Wolf359',
#  'Hotcisawesome',
#  'zintay',
#  'ei457yt',
#  'Archi_Dreams',
#  'Middlen',
#  'bardtothebone',
#  'eggnode',
#  'sittingoverheredreaming',
#  'HistoricalImmaterialism',
#  'Celesteria',
#  'dreamerofrealities',
#  'mitumial',
#  'PRationality',
#  'Yardofjaffa',
#  'WhatLetterAreWeTalkingAbout',
#  'lytefoot',
#  'flannelboi7',
#  'ahto',
#  'malosaires',
#  'GretaaSad',
#  'FreekayFresh',
#  'docmatoi',
#  'Bi_Reader_16',
#  'saime13',
#  'claireistheangelofhellskitchen',
#  'fmriver',
#  'NaughtyNix96',
#  'verboseDescription',
#  'ThatOneInTheCornerWithTheBook',
#  'angelwithaphonebox',
#  'noneislefttoprotest',
#  'Nonchalant_Lei',
#  'DatSpaceGay',
#  'adrianna912',
#  'clumsyorcwaifu',
#  'dw910',
#  'rukki',
#  'tirede',
#  'cilliem',
#  'canbethevenspell',
#  'CactusPlantPot',
#  'AkatsukinoRuby',
#  'MapuMaps',
#  'astrohyun',
#  'ladders',
#  'Crying_Over_Littlethings',
#  'secretiveAstrologer',
#  'Faded_Emerald',
#  'zellymaybloom',
#  'BlinkyChild',
#  'Phoenixhero',
#  'UnpopularFanfictions',
#  'bowpennykettle',
#  'Work_Of_Art',
#  'marstars',
#  'Faith1212',
#  'AwkwardGayBean',
#  'Gnom',
#  'Snow0404',
#  'MurderChick',
#  'Dragonofelder',
#  '1VariousStorms1',
#  'Artikka',
#  'ElvaNyaOwO',
#  'TheShippest',
#  'xSheepie',
#  'Bruhbruhbruh',
#  'OerbaYunErika',
#  'missastronaut',
#  'troubleinmind',
#  'Lilith',
#  'kinniemobile',
#  'gobes',
#  'Macarist',
#  'rawr_immadragon',
#  'BeanutButterBoy',
#  'justforfunforkicksforlaughs',
#  'Blazinggaze',
#  'CapicDaCrate',
#  '1Wanderer_moon5',
#  'ANeonChicken',
#  'Pinkcherry135',
#  'xx_TwentyGayTeen_xx',
#  'Werederg',
#  'ConfusedCreature',
#  'Tarota4',
#  'YellowRosesAndDragons',
#  'EmyBunny',
#  'InfiniteOreos',
#  'Largishcat',
#  'gabriellestardust48',
#  'Kreadsalot',
#  'DoingitfortheDishes',
#  'SaphireStain',
#  'soft_gays',
#  'Probably_yang',
#  'Superceoluv',
#  'EmeraHeals',
#  'shinebrightlikeanimon',
#  'galaxymir',
#  'YoungDragon',
#  'jessisconfused',
#  'peanut_gallery_ghostwriter',
#  'theCherub',
#  'spacedumbass',
#  'MargaretEverfree',
#  'batsyzatara',
#  'GallavichAllDay',
#  'sunkissed_teardrops',
#  'AnDeasAriana',
#  'Rexthedinoo',
#  'swag_gender',
#  'Kismetcanbiteme',
#  'Zirael_stan',
#  'theboilingrock',
#  'WolfmanMcGee',
#  'Hitchhicker',
#  'xobsidienne',
#  'cloudlines',
#  'Hessy',
#  'deadbeatdevin',
#  'moons-of-mars (moonsofmars)',
#  'lifeofbubbles',
#  'Insanity_Smiles',
#  'cinderflubbin',
#  'sparkyneedsadoctor',
#  'metriculous',
#  'stellarscapes',
#  'PlsLetMeSleeb',
#  'Shelby85',
#  'china4345',
#  'khattikeri',
#  'pottergerms',
#  'BookNerd1231',
#  'SpiderDeity',
#  'AddictedAlternate',
#  'kittykatkiki',
#  'xnatsuk',
#  'Nomonoke',
#  'lolloy',
#  'Readingnerd22',
#  'Ghostly_Prince',
#  'FangirlofMany9503',
#  'sathyasrini302',
#  'Feather_Quill_Ambition',
#  'GinaLovesZero',
#  'Screamingsquider',
#  'Reader1865',
#  'Fez_derptor',
#  'WordsAndWorlds',
#  'relliketh',
#  'The_Clever_Rose',
#  'Moooses',
#  'Classyelll',
#  'Sketchy_Artist',
#  'stroke_of_genius',
#  'DrunkNote',
#  'Hoofengoofer',
#  'AngieWritesStuff',
#  'azumarheart',
#  'booksRlyfe',
#  'infestedsoul',
#  'nernerune',
#  'thespacethatsurroundsyou',
#  'femdykes',
#  'AeschylusRex',
#  'Soann',
#  'dvenerys',
#  'goodtea',
#  'd72ksd5',
#  'spirallingnotes',
#  'toorukinn1e',
#  'RogueTomato101',
#  'sictransitgloriamundi',
#  'SilverOak',
#  'PokeMaster_Zelda',
#  'Pavonisa',
#  'Say_it_softer (Say_Anything)',
#  'Laughingstock_16',
#  'immortalvessel',
#  'gayy',
#  'Daytona444',
#  'LAFD118_LAPD22',
#  'Dragonbano',
#  'NaiveAsAlways',
#  'andrewjet',
#  'DoughballZ',
#  'H_is_alive',
#  'Acrid',
#  'ai_sana',
#  'theexhaustedalchemist',
#  'Dumbass_Enby',
#  'Jynx_717',
#  'tiffanytheweirdo',
#  'SleepyRat',
#  'Chuchu2004',
#  'AryaAckerman',
#  'ChaseDawg12',
#  'GeekyLesbian',
#  'Pennyforyourthoughts',
#  'estullefavric',
#  'dayershiper',
#  'rockgodassasin',
#  'zorelklaus',
#  'harkness',
#  'Savium',
#  'Subject_of_Ridicule',
#  'LittleBakemono',
#  'LineLi225',
#  'Zaceria',
#  'sonny_elizabeth',
#  'Shitty_Shipper',
#  'AwesomeWizard7',
#  'Imadorable',
#  'Unseasonedfish',
#  'enby_named_Arrow',
#  'Lyssandra_Med',
#  'Eival',
#  'SwampFairy',
#  '0o0_Winter_Wolf_0o0',
#  'ace',
#  'TabbyPanther',
#  'clexstein',
#  'nillawave',
#  '2disreference',
#  'keithlovebot',
#  'Foxipaw',
#  'LovetoReader',
#  'I_have_no_life_pls_help',
#  'waffleloser',
#  'Faronna426',
#  'NiyanaIsNotSane',
#  'sapphicjasper',
#  'AbigailsBigToe777',
#  'enrose',
#  'inkubusmb',
#  '1_step2_steps',
#  'vph',
#  'AnIdiotOfYourOwn',
#  'nightmonkey2019',
#  'fitzefitcher',
#  'WhisperedSecrets',
#  'Opticpotatofish',
#  'e_e_s_h_a',
#  'floweredhalo',
#  'bluesnowflakelily',
#  'Malachi_Eclipse',
#  'PurpleCatsAndSandersSidesAreLife',
#  'recurvehawk',
#  'Idrfc27',
#  'Arlyana',
#  'Scribblepausescribble',
#  'bellestaegi',
#  'Broccolithing',
#  'LittleOneWingedAngel',
#  'Imoomin',
#  'Smalls',
#  'soapsuds',
#  'RRESO8',
#  'stitchingatthecircuitboard',
#  'OptionA',
#  'Pausa07',
#  'Skinned_Yeen',
#  'knifelesbian',
#  'ShadowDragonstone',
#  'Annde',
#  'androdyke',
#  'IceSapphireSerpent',
#  'TestRun21',
#  'fairviolets',
#  'Anxiousandstressed',
#  'CloudedWater',
#  'Coppacola',
#  'A_cool_penguin',
#  'MamaStayfit',
#  'calendulae',
#  'w1z3rrd',
#  'npat32',
#  'ferrero25',
#  'BsuKie',
#  'ladyofthedykes',
#  'Asteroth',
#  'CopDog',
#  'vivalakoala',
#  'candyfloss_and_soy_milk',
#  'weirdo_has_arrived',
#  'yeahsureray',
#  'rivernightshade21',
#  'Crazypuff33',
#  'Badum_tsh',
#  'Madaline99',
#  'RainingConstellations',
#  'BluTiger13',
#  'sampaguitaeiji',
#  'the_koala_boi',
#  'mheekies_lover1',
#  'lordcedrek1',
#  'concertconfetti',
#  'Maleficent',
#  'DarkSnoww',
#  'ikjunholic',
#  'EmberFreespirit',
#  'PaintPott',
#  'FeralWaffle',
#  'lostlesbian',
#  'Bluechupathingy',
#  'MorrisonFord',
#  'AttackoftheDarkCurses',
#  'nemesisempyree1',
#  'wolfyraged',
#  'legendofbtvs08',
#  'Baivaca',
#  'Cakesp',
#  'FoeHammer',
#  'Isaadora',
#  'GoodKingOridan',
#  'Rowan12628',
#  'Iry_Loves_Camila',
#  'Ladycabbageface',
#  'hitomishiga',
#  'truthrunswild',
#  'millepertuis',
#  'ValourDyke',
#  'adoras_trap',
#  'jushiiisushiii',
#  'justanji',
#  'Sanmarino14',
#  'Im_gay_weeb',
#  'julesby10',
#  'Lifeoverlimb',
#  'Lady_Ashla_Tano',
#  'TaihChan',
#  'JoshThePleb',
#  'Spawn_of_Say10',
#  'Gold_lime',
#  'Smartwatson',
#  'virtutyphoon',
#  'GuerrillaWarfare',
#  'Plot_Yeast',
#  'RoseCMallow',
#  'Findlaykb',
#  'Arkah',
#  'fuyfuyfuy',
#  'ekgogel',
#  'balkani',
#  'splatt04',
#  'Eggsbenedictcumberbund',
#  'Grego',
#  'JesGhost',
#  'hblankm',
#  'rarefiedrest',
#  'Kchau',
#  'Zutiala',
#  'Fire_Wolf',
#  'Jazzyroll',
#  'Kero13',
#  'ann_a_mac',
#  'sandssavvy',
#  'toad_in_the_road',
#  'AdeleDazeem',
#  'DValkyrie',
#  'Dad_Energy',
#  'Twasbutonceaboy',
#  'bagelst',
#  'ember_celica',
#  'aether_arting',
#  'hypsterghoul666',
#  'barbequetongs',
#  'Jynxtaposition',
#  'KC2',
#  'damndani',
#  'MugiwaraDecepticon',
#  'RoadsOfShadow',
#  'Lrabbithole',
#  'sjg09',
#  'Abc112',
#  'DaxxyTeapot',
#  'cloudtreesium',
#  'Arten',
#  'CherryL0v3',
#  'blightguts',
#  'fivebyfreakingfive',
#  'Unisparkle05',
#  'kitewolf',
#  'Tinygaygreyjoy',
#  'acerbicwit',
#  'Room_Temperature_Fruit',
#  'CamiMello',
#  'Kuhaoyaoi',
#  'garneroo',
#  'Esahc',
#  'Bacon3600',
#  'Ren_Dreamt_The_Cosmos',
#  'eevangi',
#  'Gaploon',
#  'BrennanShorter',
#  'QueenRiza',
#  'oogabooga',
#  'Cowzilla',
#  'betaniamber',
#  'krytisx',
#  'KanaMariOTP',
#  'Dljm',
#  'HopefulPenguin',
#  'Rolyghost',
#  'mirakeilde',
#  'AnimeWolf04',
#  'Anonymous_KitKat',
#  'HuepfKaese',
#  'SecretMarcy',
#  'bizzybee',
#  'foartie',
#  'Winter_Wolf101',
#  'FizzyLimePop',
#  'Blue_Monday',
#  'fromxthexvalley',
#  'littleA',
#  'Corvax',
#  'cilantrobot',
#  'goldgalaxytea',
#  'dersedoodles',
#  'aftergl0w',
#  'lisnna',
#  'amiabadperson',
#  'CDRomelle',
#  'typicallydepressedandanxious',
#  'LockandKeyHyena',
#  'aucatgirl',
#  'TwinOcted',
#  'MisaLacksPersonality',
#  'stellar_revelation',
#  'OrieJai',
#  'HummingSmoi',
#  'NeedsGroup',
#  'queerghstbuster',
#  'TheYetiMag_overallsimp',
#  'YourSkittleLover',
#  'FatedFire',
#  'MagicalEzran',
#  'SparksAmidstSnow',
#  'missbakugo',
#  'lizzieslegacy',
#  'unlesshate',
#  'The_Descolada',
#  'mickeydubs',
#  'Demonic_Jay',
#  'nightmaster000',
#  'Nehirani',
#  'InterdimensionalMonsterHero',
#  'carrymeimTired',
#  'Marzbar',
#  'dreamBubbler',
#  'Elynx',
#  'rundmc1026',
#  'firclily',
#  'Okamira',
#  'kasanife',
#  'TheOriginalJock',
#  'littlefowlee',
#  'NyaTali',
#  'Daybreak_993',
#  'newfaith',
#  'GoddessOfDarkness97',
#  'sadrobotinahat',
#  'poordisguise',
#  'ChaosBessie',
#  'MistressK10',
#  'Supergeekgirl05',
#  'adoragay',
#  'AncientElemental',
#  'TrueBlueNihil',
#  'Omahdon',
#  'jules8178',
#  'kimchikat',
#  'Ms_hats22',
#  'coucou1023',
#  'groves625',
#  'ms_134340',
#  'Ialwayskeepshipping',
#  'snowbazami',
#  'shifra',
#  'keyhallin',
#  'Registeredmember',
#  'Toast4219',
#  'Todteufelritter',
#  'SilkyinaBottle',
#  'Heysia',
#  'viixiie',
#  'Idiotic_gryffindor',
#  'Ongaku',
#  'Elliecantswim',
#  'mylifeisASeriesOfUnfortunateEvents',
#  'NotWhatYuuThink',
#  'MAYbeVampire',
#  'SuperDog75',
#  'Enjolsad',
#  'capricEntropy',
#  'paula_espi',
#  'holmesherl',
#  'amysjbjhb',
#  'chunni',
#  'thalassatra',
#  'moldychedd',
#  'heyjules',
#  'SnowyDawn17',
#  'Gillingswater',
#  'pinkishdye',
#  'Cups_left_over',
#  'Pantamalion',
#  'SpaceSaucepan',
#  'tiny_baby_zucchini',
#  'Nicky308',
#  'InclinedTo_Disagree',
#  'SD114',
#  'SpearmintDream',
#  'cqrvid',
#  'allwedoissurvive',
#  'Reddings',
#  'Silvertounge',
#  'WhiteWater0',
#  'Kamaki',
#  'Axskalotl',
#  'StrawberryOverlord',
#  'aWildLu',
#  'Scumfucker',
#  'Dark_Wolf_98',
#  'breadandroses',
#  'vengefularia',
#  'Rlillies',
#  'If_Its_Gay_I_Probably_Ship_It',
#  'addicted2reading16',
#  'iammemai',
#  'Elena_Lavorre',
#  'heliconn',
#  'Atrals',
#  'mleo10',
#  'Magiber',
#  'rosegoldsocks',
#  'YOU_ME_AT_SIX',
#  'Anansi_Weaver_of_Stories',
#  'Squig011',
#  'carpe_nocten',
#  'Mania71',
#  'justanotherfan11',
#  'purplemoonabove',
#  'dmelisa9',
#  'Until_today',
#  'Cain_black',
#  'LyrZetara',
#  'Oh_Taco',
#  'optimisticlesbian',
#  'souLLdark',
#  'Kathendale',
#  'SonGoharotto',
#  'dans_la_neige',
#  'CriticalGoose',
#  'Hexicangel',
#  'TheMusicMetroid',
#  'social_dissident',
#  'IndelibleSpock',
#  'LakaFlower',
#  'SheRasPitcher',
#  'heavyweaponsgirl',
#  'ChaosBees267',
#  'BastardfromWinterfell',
#  'bisexualpunk',
#  'Cynthiathepotato',
#  'monsterq',
#  'ai_laik_trash',
#  'kathime',
#  'mimi333',
#  'ziphos',
#  'Giraffacake',
#  'Wolfie7877',
#  'VelliJelli',
#  'lvecean',
#  'rwbykaje24',
#  'sundaramenashe',
#  'bubbIine',
#  'mangofree',
#  'MopSink',
#  'merrymaya',
#  'absolutely_any_fandom',
#  'xxuchii',
#  'Paquito09',
#  'andromeduh',
#  'Verdant_Mint_Tea',
#  'bibliofago',
#  'EmKemper',
#  'Zenish',
#  'WeissSchneesFannyPack',
#  'Adaka',
#  'martatoba',
#  'lyingbeast',
#  'korrasbitch',
#  'Mujoona',
#  'Sunshine101010',
#  'JacckWill',
#  'grabbymyarse',
#  'faustin',
#  ...}

# %%
e = Exception('asdf')

# %%
session.rollback()

# %%
len(works)
# Out:
# 11734
